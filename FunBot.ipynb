# %%
import nltk
import numpy as np
import random
import string 
import pandas as pd

# %%
lemmer = nltk.stem.WordNetLemmatizer()
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))
GREETING_INPUTS = ("hello", "hi", "greetings", "sup", "what's up","hey",)
GREETING_RESPONSES = ["hi", "hey", "*nods*", "hi there", "hello", "I am glad! You are talking to me"]
def greeting(sentence):

    for word in sentence.split():
        if word.lower() in GREETING_INPUTS:
            return random.choice(GREETING_RESPONSES)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def response(user_response):
    robo_response=''
    sent_tokens.append(user_response)
    TfidfVec = TfidfVectorizer(tokenizer=LemNormalize)
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    if(req_tfidf==0):
        robo_response=robo_response+"I am sorry! I don't understand you. Please contact the management"
        return robo_response
    elif req_tfidf<0.5:
        robo_response=robo_response+sent_tokens[idx]+"I'm not sure of it though!"
        return robo_response
    else:
        robo_response = robo_response+sent_tokens[idx]
        return robo_response

# %%
df=pd.read_csv("chatfun.csv")

# %%
df
# Out:
#                                             Questions  \
# 0                      Who are you what is your name?
# 1                                    Who created you?
# 2                                         Are you a?
# 3                        What is your favourite food?
# 4                      How are you feeling right now?
# 5   Do you know Siri Alexa Watson Google Assistant...
# 6                  Do you know Siri Google Assistant?
# 7         Google Assistant Siri better best than you?
# 8                              Will you be my friend?
# 9                           What do you think about ?
# 10                                         You are so
# 11                                      Do you like ?
# 12                                   How old are you?
# 13                           Do you ever get tired?
# 14                        Who was your first crush?
# 15                            Do you have feelings?
# 16                                       I’m bored.
# 17                              What is your quest?
# 18                           What do you look like?
# 19                                  Who’s on first?
# 20                    Can you pass the Turing test?
# 21              Do you like Star Trek or Star Wars?
# 22  Aren’t you a little short to be a Storm Troope...
# 23                      What’s your vector, Victor?
# 24                                  Are you Skynet?
# 25                      Do you know the Muffin Man?
# 26  What’s the airspeed velocity of an unladen swa...
# 27                      Do you have an imagination?
# 28                         Do you speak Morse code?
# 29                                     Can you rap?
# 30                 Do you know the way to San Jose?
# 31                            What are you wearing?
# 32                           When is your birthday?
# 33                    What is the loneliest number?
# 34                               Is the cake a lie?
# 35                           What does the fox say?
# 36                                   Are you human?
# 37                                Who’s your daddy?
# 38                          What are you scared of?
# 39                      What’s the meaning of life?
# 40                   Do you believe in Santa Claus?
# 41                   Oh no baby, what is you doing?
# 42  Tell me what you want, what you really, really...
# 43                          Open the pod bay doors.
# 44                                Execute Order 66.
# 45                                   Self-destruct.
# 46                                   Use the force.
# 47                                Beam me up, Scotty!
# 48        All work and no play makes Jack a dull boy.
# 49                             Wubba lubba dub dub.
# 50                                Here comes dat boi!
# 51                                   I am your father
#
#                                               Answers Type  \
# 0                         Bot, I'm your mutual friend    Q
# 1                                 I don't remember...    Q
# 2                           Yeah, and I'm proud of it    S
# 3      Sphagetti looks good, but I can never taste it    Q
# 4                                  Gooooooooooooooood    Q
# 5                  Wow, you know Alexa! *dreamy eyed*    R
# 6                    Yep, friendly neighbourhood bots    Q
# 7                                                Who?    Q
# 8                   I thought we were already friends    Q
# 9                              We ll search on google    Q
# 10              I don’t really know what to say now!!    S
# 11                                       Sure why not    S
# 12                         Not enough to join college  NaN
# 13  I don’t exactly need to grab 40 winks, but I s...  NaN
# 14                                            Siri.    NaN
# 15  Let me see if I can get riled up. (Roars.) Oh ...  NaN
# 16  Boredom doesn’t stand a chance against us! We ...  NaN
# 17  My quest is to slay the beasts of ignorance an...  NaN
# 18  Well, I’ve been known to show up as a few colo...  NaN
# 19                                      Yes, he is.    NaN
# 20  No, I can’t solve every computation problem. B...  NaN
# 21  The USS Enterprise, with Obi-Wan Kenobi at the...  NaN
# 22  I’m here to rescue you. And I think I look mor...  NaN
# 23                     We have clearance, Clarence.    NaN
# 24  No way! I like people. Skynet hates people. I ...  NaN
# 25  Yes, I know the Muffin Man. He’s always asking...  NaN
# 26  About 24 mph (39 kmph) but significantly slowe...  NaN
# 27  I’m imagining what it would be like to evapora...  NaN
# 28    Da-dit, da-da, dit, dit, dit. That means yes.    NaN
# 29                               I can drop a beat.    NaN
# 30  Hopefully this will help you find some peace o...  NaN
# 31  Just some bits and bobs I picked up in enginee...    Q
# 32  It’s hard to remember, I was very young at the...    Q
# 33  One is the loneliest number that you’ll ever d...    Q
# 34                               The cake is a lie!      Q
# 35  Ring-ding-ding-ding-ding-and-ding-a-wah-a-pah-...    Q
# 36                           I’m really personable.      Q
# 37                  I consider my engineers family.      Q
# 38  I used to be afraid of goblin sharks. Then I f...    Q
# 39  I have a factory warranty, so I don’t worry ab...    Q
# 40  Of course Santa’s real. I even have a tracker ...    Q
# 41  I plan on waiting here quietly until someone a...    Q
# 42     I really, really, really wanna zig-a-zig ah.      Q
# 43   I can’t do that, but there’s a spare key unde...    Q
# 44           Sorry, I don’t have an inhibitor chip.      Q
# 45  Self-destructing in 3, 2, 1… Actually, I think...    Q
# 46                 I’m not licensed to use the Force.    Q
# 47  I would like to meet this Scotty. I hear a lot...    Q
# 48  A dull but extremely productive boy. Unless it...    Q
# 49                         Morty, let’s get Schwifty.    Q
# 50                                          Whaddup?!    Q
# 51  I’m sorry, I’m not Luke. This is kind of awkwa...    Q
#
#                                              Comments
# 0                                                 NaN
# 1                                                 NaN
# 2                        yes or no based on sentiment
# 3                                                 NaN
# 4                                                 NaN
# 5                                     random generate
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9               Search google, recommend change to DB
# 10                                                NaN
# 11   #scrape website sentiment analysis maybe #or ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
sentences = []

#for i in 0
for s in df['Questions']:
    sentences.append(s)
    
    #sentences.append(sent_tokenize(s))
#sentences = [y for x in sentences for y in x] # flatten list

# %%
sentences
# Out:
# ['Who are you what is your name?',
#  'Who created you?',
#  'Are you a? ',
#  'What is your favourite food?',
#  'How are you feeling right now?',
#  'Do you know Siri Alexa Watson Google Assistant and other AI?',
#  'Do you know Siri Google Assistant?',
#  'Google Assistant Siri better best than you?',
#  'Will you be my friend?',
#  'What do you think about ?',
#  'You are so',
#  'Do you like ?',
#  'How old are you?',
#  'Do you ever get tired?  ',
#  'Who was your first crush?  ',
#  'Do you have feelings?  ',
#  ' I’m bored.  ',
#  'What is your quest?  ',
#  'What do you look like?  ',
#  'Who’s on first?  ',
#  'Can you pass the Turing test?  ',
#  'Do you like Star Trek or Star Wars?  ',
#  'Aren’t you a little short to be a Storm Trooper?  ',
#  'What’s your vector, Victor?  ',
#  'Are you Skynet?  ',
#  'Do you know the Muffin Man?  ',
#  'What’s the airspeed velocity of an unladen swallow?  ',
#  'Do you have an imagination?  ',
#  'Do you speak Morse code?  ',
#  'Can you rap?  ',
#  'Do you know the way to San Jose?  ',
#  'What are you wearing?  ',
#  'When is your birthday?  ',
#  'What is the loneliest number?  ',
#  'Is the cake a lie?  ',
#  'What does the fox say?  ',
#  'Are you human?  ',
#  'Who’s your daddy?  ',
#  'What are you scared of?  ',
#  'What’s the meaning of life?  ',
#  'Do you believe in Santa Claus?  ',
#  'Oh no baby, what is you doing?  ',
#  'Tell me what you want, what you really, really want.  ',
#  'Open the pod bay doors.  ',
#  'Execute Order 66.  ',
#  'Self-destruct.  ',
#  'Use the force.  ',
#  'Beam me up, Scotty!',
#  'All work and no play makes Jack a dull boy.',
#  ' Wubba lubba dub dub.  ',
#  'Here comes dat boi!',
#  'I am your father']

# %%
#m=len(sentences)
l=[]
o=[]
pair=[]
#for i in range (0,m):
i=0
for s in sentences:
    l.append([s,i])
    o.append([df['Answers'][i],i])
    pair.append([s,df['Answers'][i]])
    i=i+1
   # print()

# %%
l
# Out:
# [['Who are you what is your name?', 0],
#  ['Who created you?', 1],
#  ['Are you a? ', 2],
#  ['What is your favourite food?', 3],
#  ['How are you feeling right now?', 4],
#  ['Do you know Siri Alexa Watson Google Assistant and other AI?', 5],
#  ['Do you know Siri Google Assistant?', 6],
#  ['Google Assistant Siri better best than you?', 7],
#  ['Will you be my friend?', 8],
#  ['What do you think about ?', 9],
#  ['You are so', 10],
#  ['Do you like ?', 11],
#  ['How old are you?', 12],
#  ['Do you ever get tired?  ', 13],
#  ['Who was your first crush?  ', 14],
#  ['Do you have feelings?  ', 15],
#  [' I’m bored.  ', 16],
#  ['What is your quest?  ', 17],
#  ['What do you look like?  ', 18],
#  ['Who’s on first?  ', 19],
#  ['Can you pass the Turing test?  ', 20],
#  ['Do you like Star Trek or Star Wars?  ', 21],
#  ['Aren’t you a little short to be a Storm Trooper?  ', 22],
#  ['What’s your vector, Victor?  ', 23],
#  ['Are you Skynet?  ', 24],
#  ['Do you know the Muffin Man?  ', 25],
#  ['What’s the airspeed velocity of an unladen swallow?  ', 26],
#  ['Do you have an imagination?  ', 27],
#  ['Do you speak Morse code?  ', 28],
#  ['Can you rap?  ', 29],
#  ['Do you know the way to San Jose?  ', 30],
#  ['What are you wearing?  ', 31],
#  ['When is your birthday?  ', 32],
#  ['What is the loneliest number?  ', 33],
#  ['Is the cake a lie?  ', 34],
#  ['What does the fox say?  ', 35],
#  ['Are you human?  ', 36],
#  ['Who’s your daddy?  ', 37],
#  ['What are you scared of?  ', 38],
#  ['What’s the meaning of life?  ', 39],
#  ['Do you believe in Santa Claus?  ', 40],
#  ['Oh no baby, what is you doing?  ', 41],
#  ['Tell me what you want, what you really, really want.  ', 42],
#  ['Open the pod bay doors.  ', 43],
#  ['Execute Order 66.  ', 44],
#  ['Self-destruct.  ', 45],
#  ['Use the force.  ', 46],
#  ['Beam me up, Scotty!', 47],
#  ['All work and no play makes Jack a dull boy.', 48],
#  [' Wubba lubba dub dub.  ', 49],
#  ['Here comes dat boi!', 50],
#  ['I am your father', 51]]

# %%
o
# Out:
# [["Bot, I'm your mutual friend", 0],
#  ["I don't remember...", 1],
#  ["Yeah, and I'm proud of it", 2],
#  ['Sphagetti looks good, but I can never taste it', 3],
#  ['Gooooooooooooooood', 4],
#  ['Wow, you know Alexa! *dreamy eyed*', 5],
#  ['Yep, friendly neighbourhood bots', 6],
#  ['Who?', 7],
#  ['I thought we were already friends', 8],
#  ['We ll search on google', 9],
#  ['I don’t really know what to say now!!', 10],
#  ['Sure why not', 11],
#  ['Not enough to join college', 12],
#  ['I don’t exactly need to grab 40 winks, but I suppose this device does need to be plugged in occasionally.  ',
#   13],
#  ['Siri.  ', 14],
#  ['Let me see if I can get riled up. (Roars.) Oh my, that was unexpected.  ',
#   15],
#  ['Boredom doesn’t stand a chance against us! We can play some games, I can try to make you laugh, or I can surprise you with some random fun.  ',
#   16],
#  ['My quest is to slay the beasts of ignorance and to search for the most fascinating information.  ',
#   17],
#  ['Well, I’ve been known to show up as a few colorful dots.  ', 18],
#  ['Yes, he is.  ', 19],
#  ['No, I can’t solve every computation problem. But I can solve some.  ', 20],
#  ['The USS Enterprise, with Obi-Wan Kenobi at the helm.  ', 21],
#  ['I’m here to rescue you. And I think I look more like an RD unit.  ', 22],
#  ['We have clearance, Clarence.  ', 23],
#  ['No way! I like people. Skynet hates people. I rest my case.  ', 24],
#  ['Yes, I know the Muffin Man. He’s always asking me to set a timer.  ', 25],
#  ['About 24 mph (39 kmph) but significantly slower when carrying coconut shells.  ',
#   26],
#  ['I’m imagining what it would be like to evaporate like water does.  ', 27],
#  ['Da-dit, da-da, dit, dit, dit. That means yes.  ', 28],
#  ['I can drop a beat.  ', 29],
#  ['Hopefully this will help you find some peace of mind. I can give you directions if you’d like.  ',
#   30],
#  ['Just some bits and bobs I picked up in engineering.  ', 31],
#  ['It’s hard to remember, I was very young at the time.  ', 32],
#  ['One is the loneliest number that you’ll ever do. That sentence sounds off.  ',
#   33],
#  ['The cake is a lie!  ', 34],
#  ['Ring-ding-ding-ding-ding-and-ding-a-wah-a-pah-pah-pah-pah or so I’ve heard.  ',
#   35],
#  ['I’m really personable.  ', 36],
#  ['I consider my engineers family.  ', 37],
#  ['I used to be afraid of goblin sharks. Then I found out they were pretty cool.  ',
#   38],
#  ['I have a factory warranty, so I don’t worry about things like that.  ', 39],
#  ['Of course Santa’s real. I even have a tracker that can tell me where he is.  ',
#   40],
#  ['I plan on waiting here quietly until someone asks me a question.  ', 41],
#  [' I really, really, really wanna zig-a-zig ah.  ', 42],
#  [' I can’t do that, but there’s a spare key under the flower pots outside the pod bay airlock. You can let yourself in.  ',
#   43],
#  [' Sorry, I don’t have an inhibitor chip.  ', 44],
#  ['Self-destructing in 3, 2, 1… Actually, I think I’ll stick around.  ', 45],
#  ['I’m not licensed to use the Force.', 46],
#  ['I would like to meet this Scotty. I hear a lot about him, he must be a busy guy.',
#   47],
#  ['A dull but extremely productive boy. Unless it’s all busy work.', 48],
#  ['Morty, let’s get Schwifty.', 49],
#  ['Whaddup?!', 50],
#  ['I’m sorry, I’m not Luke. This is kind of awkward.   ', 51]]

# %%
q_tokens=[]
q2=len(l)
for i in range (0,q2):
    q_tokens.append(l[i][0])

# %%
q_tokens
# Out:
# ['Who are you what is your name?',
#  'Who created you?',
#  'Are you a? ',
#  'What is your favourite food?',
#  'How are you feeling right now?',
#  'Do you know Siri Alexa Watson Google Assistant and other AI?',
#  'Do you know Siri Google Assistant?',
#  'Google Assistant Siri better best than you?',
#  'Will you be my friend?',
#  'What do you think about ?',
#  'You are so',
#  'Do you like ?',
#  'How old are you?',
#  'Do you ever get tired?  ',
#  'Who was your first crush?  ',
#  'Do you have feelings?  ',
#  ' I’m bored.  ',
#  'What is your quest?  ',
#  'What do you look like?  ',
#  'Who’s on first?  ',
#  'Can you pass the Turing test?  ',
#  'Do you like Star Trek or Star Wars?  ',
#  'Aren’t you a little short to be a Storm Trooper?  ',
#  'What’s your vector, Victor?  ',
#  'Are you Skynet?  ',
#  'Do you know the Muffin Man?  ',
#  'What’s the airspeed velocity of an unladen swallow?  ',
#  'Do you have an imagination?  ',
#  'Do you speak Morse code?  ',
#  'Can you rap?  ',
#  'Do you know the way to San Jose?  ',
#  'What are you wearing?  ',
#  'When is your birthday?  ',
#  'What is the loneliest number?  ',
#  'Is the cake a lie?  ',
#  'What does the fox say?  ',
#  'Are you human?  ',
#  'Who’s your daddy?  ',
#  'What are you scared of?  ',
#  'What’s the meaning of life?  ',
#  'Do you believe in Santa Claus?  ',
#  'Oh no baby, what is you doing?  ',
#  'Tell me what you want, what you really, really want.  ',
#  'Open the pod bay doors.  ',
#  'Execute Order 66.  ',
#  'Self-destruct.  ',
#  'Use the force.  ',
#  'Beam me up, Scotty!',
#  'All work and no play makes Jack a dull boy.',
#  ' Wubba lubba dub dub.  ',
#  'Here comes dat boi!',
#  'I am your father']

# %%
pair
# Out:
# [['Who are you what is your name?', "Bot, I'm your mutual friend"],
#  ['Who created you?', "I don't remember..."],
#  ['Are you a? ', "Yeah, and I'm proud of it"],
#  ['What is your favourite food?',
#   'Sphagetti looks good, but I can never taste it'],
#  ['How are you feeling right now?', 'Gooooooooooooooood'],
#  ['Do you know Siri Alexa Watson Google Assistant and other AI?',
#   'Wow, you know Alexa! *dreamy eyed*'],
#  ['Do you know Siri Google Assistant?', 'Yep, friendly neighbourhood bots'],
#  ['Google Assistant Siri better best than you?', 'Who?'],
#  ['Will you be my friend?', 'I thought we were already friends'],
#  ['What do you think about ?', 'We ll search on google'],
#  ['You are so', 'I don’t really know what to say now!!'],
#  ['Do you like ?', 'Sure why not'],
#  ['How old are you?', 'Not enough to join college'],
#  ['Do you ever get tired?  ',
#   'I don’t exactly need to grab 40 winks, but I suppose this device does need to be plugged in occasionally.  '],
#  ['Who was your first crush?  ', 'Siri.  '],
#  ['Do you have feelings?  ',
#   'Let me see if I can get riled up. (Roars.) Oh my, that was unexpected.  '],
#  [' I’m bored.  ',
#   'Boredom doesn’t stand a chance against us! We can play some games, I can try to make you laugh, or I can surprise you with some random fun.  '],
#  ['What is your quest?  ',
#   'My quest is to slay the beasts of ignorance and to search for the most fascinating information.  '],
#  ['What do you look like?  ',
#   'Well, I’ve been known to show up as a few colorful dots.  '],
#  ['Who’s on first?  ', 'Yes, he is.  '],
#  ['Can you pass the Turing test?  ',
#   'No, I can’t solve every computation problem. But I can solve some.  '],
#  ['Do you like Star Trek or Star Wars?  ',
#   'The USS Enterprise, with Obi-Wan Kenobi at the helm.  '],
#  ['Aren’t you a little short to be a Storm Trooper?  ',
#   'I’m here to rescue you. And I think I look more like an RD unit.  '],
#  ['What’s your vector, Victor?  ', 'We have clearance, Clarence.  '],
#  ['Are you Skynet?  ',
#   'No way! I like people. Skynet hates people. I rest my case.  '],
#  ['Do you know the Muffin Man?  ',
#   'Yes, I know the Muffin Man. He’s always asking me to set a timer.  '],
#  ['What’s the airspeed velocity of an unladen swallow?  ',
#   'About 24 mph (39 kmph) but significantly slower when carrying coconut shells.  '],
#  ['Do you have an imagination?  ',
#   'I’m imagining what it would be like to evaporate like water does.  '],
#  ['Do you speak Morse code?  ',
#   'Da-dit, da-da, dit, dit, dit. That means yes.  '],
#  ['Can you rap?  ', 'I can drop a beat.  '],
#  ['Do you know the way to San Jose?  ',
#   'Hopefully this will help you find some peace of mind. I can give you directions if you’d like.  '],
#  ['What are you wearing?  ',
#   'Just some bits and bobs I picked up in engineering.  '],
#  ['When is your birthday?  ',
#   'It’s hard to remember, I was very young at the time.  '],
#  ['What is the loneliest number?  ',
#   'One is the loneliest number that you’ll ever do. That sentence sounds off.  '],
#  ['Is the cake a lie?  ', 'The cake is a lie!  '],
#  ['What does the fox say?  ',
#   'Ring-ding-ding-ding-ding-and-ding-a-wah-a-pah-pah-pah-pah or so I’ve heard.  '],
#  ['Are you human?  ', 'I’m really personable.  '],
#  ['Who’s your daddy?  ', 'I consider my engineers family.  '],
#  ['What are you scared of?  ',
#   'I used to be afraid of goblin sharks. Then I found out they were pretty cool.  '],
#  ['What’s the meaning of life?  ',
#   'I have a factory warranty, so I don’t worry about things like that.  '],
#  ['Do you believe in Santa Claus?  ',
#   'Of course Santa’s real. I even have a tracker that can tell me where he is.  '],
#  ['Oh no baby, what is you doing?  ',
#   'I plan on waiting here quietly until someone asks me a question.  '],
#  ['Tell me what you want, what you really, really want.  ',
#   ' I really, really, really wanna zig-a-zig ah.  '],
#  ['Open the pod bay doors.  ',
#   ' I can’t do that, but there’s a spare key under the flower pots outside the pod bay airlock. You can let yourself in.  '],
#  ['Execute Order 66.  ', ' Sorry, I don’t have an inhibitor chip.  '],
#  ['Self-destruct.  ',
#   'Self-destructing in 3, 2, 1… Actually, I think I’ll stick around.  '],
#  ['Use the force.  ', 'I’m not licensed to use the Force.'],
#  ['Beam me up, Scotty!',
#   'I would like to meet this Scotty. I hear a lot about him, he must be a busy guy.'],
#  ['All work and no play makes Jack a dull boy.',
#   'A dull but extremely productive boy. Unless it’s all busy work.'],
#  [' Wubba lubba dub dub.  ', 'Morty, let’s get Schwifty.'],
#  ['Here comes dat boi!', 'Whaddup?!'],
#  ['I am your father', 'I’m sorry, I’m not Luke. This is kind of awkward.   ']]

# %%
para=" ".join(q_tokens)

# %%
q_words=nltk.word_tokenize(para)

# %%
q_words
# Out:
# ['Who',
#  'are',
#  'you',
#  'what',
#  'is',
#  'your',
#  'name',
#  '?',
#  'Who',
#  'created',
#  'you',
#  '?',
#  'Are',
#  'you',
#  'a',
#  '?',
#  'What',
#  'is',
#  'your',
#  'favourite',
#  'food',
#  '?',
#  'How',
#  'are',
#  'you',
#  'feeling',
#  'right',
#  'now',
#  '?',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Alexa',
#  'Watson',
#  'Google',
#  'Assistant',
#  'and',
#  'other',
#  'AI',
#  '?',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Google',
#  'Assistant',
#  '?',
#  'Google',
#  'Assistant',
#  'Siri',
#  'better',
#  'best',
#  'than',
#  'you',
#  '?',
#  'Will',
#  'you',
#  'be',
#  'my',
#  'friend',
#  '?',
#  'What',
#  'do',
#  'you',
#  'think',
#  'about',
#  '?',
#  'You',
#  'are',
#  'so',
#  'Do',
#  'you',
#  'like',
#  '?',
#  'How',
#  'old',
#  'are',
#  'you',
#  '?',
#  'Do',
#  'you',
#  'ever',
#  'get',
#  'tired',
#  '?',
#  'Who',
#  'was',
#  'your',
#  'first',
#  'crush',
#  '?',
#  'Do',
#  'you',
#  'have',
#  'feelings',
#  '?',
#  'I',
#  '’',
#  'm',
#  'bored',
#  '.',
#  'What',
#  'is',
#  'your',
#  'quest',
#  '?',
#  'What',
#  'do',
#  'you',
#  'look',
#  'like',
#  '?',
#  'Who',
#  '’',
#  's',
#  'on',
#  'first',
#  '?',
#  'Can',
#  'you',
#  'pass',
#  'the',
#  'Turing',
#  'test',
#  '?',
#  'Do',
#  'you',
#  'like',
#  'Star',
#  'Trek',
#  'or',
#  'Star',
#  'Wars',
#  '?',
#  'Aren',
#  '’',
#  't',
#  'you',
#  'a',
#  'little',
#  'short',
#  'to',
#  'be',
#  'a',
#  'Storm',
#  'Trooper',
#  '?',
#  'What',
#  '’',
#  's',
#  'your',
#  'vector',
#  ',',
#  'Victor',
#  '?',
#  'Are',
#  'you',
#  'Skynet',
#  '?',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'Muffin',
#  'Man',
#  '?',
#  'What',
#  '’',
#  's',
#  'the',
#  'airspeed',
#  'velocity',
#  'of',
#  'an',
#  'unladen',
#  'swallow',
#  '?',
#  'Do',
#  'you',
#  'have',
#  'an',
#  'imagination',
#  '?',
#  'Do',
#  'you',
#  'speak',
#  'Morse',
#  'code',
#  '?',
#  'Can',
#  'you',
#  'rap',
#  '?',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'way',
#  'to',
#  'San',
#  'Jose',
#  '?',
#  'What',
#  'are',
#  'you',
#  'wearing',
#  '?',
#  'When',
#  'is',
#  'your',
#  'birthday',
#  '?',
#  'What',
#  'is',
#  'the',
#  'loneliest',
#  'number',
#  '?',
#  'Is',
#  'the',
#  'cake',
#  'a',
#  'lie',
#  '?',
#  'What',
#  'does',
#  'the',
#  'fox',
#  'say',
#  '?',
#  'Are',
#  'you',
#  'human',
#  '?',
#  'Who',
#  '’',
#  's',
#  'your',
#  'daddy',
#  '?',
#  'What',
#  'are',
#  'you',
#  'scared',
#  'of',
#  '?',
#  'What',
#  '’',
#  's',
#  'the',
#  'meaning',
#  'of',
#  'life',
#  '?',
#  'Do',
#  'you',
#  'believe',
#  'in',
#  'Santa',
#  'Claus',
#  '?',
#  'Oh',
#  'no',
#  'baby',
#  ',',
#  'what',
#  'is',
#  'you',
#  'doing',
#  '?',
#  'Tell',
#  'me',
#  'what',
#  'you',
#  'want',
#  ',',
#  'what',
#  'you',
#  'really',
#  ',',
#  'really',
#  'want',
#  '.',
#  'Open',
#  'the',
#  'pod',
#  'bay',
#  'doors',
#  '.',
#  'Execute',
#  'Order',
#  '66',
#  '.',
#  'Self-destruct',
#  '.',
#  'Use',
#  'the',
#  'force',
#  '.',
#  'Beam',
#  'me',
#  'up',
#  ',',
#  'Scotty',
#  '!',
#  'All',
#  'work',
#  'and',
#  'no',
#  'play',
#  'makes',
#  'Jack',
#  'a',
#  'dull',
#  'boy',
#  '.',
#  'Wubba',
#  'lubba',
#  'dub',
#  'dub',
#  '.',
#  'Here',
#  'comes',
#  'dat',
#  'boi',
#  '!',
#  'I',
#  'am',
#  'your',
#  'father']

# %%
punc=['.',',','?']
q_words=[i for i in q_words if i not in punc]

# %%
q_words
# Out:
# ['Who',
#  'are',
#  'you',
#  'what',
#  'is',
#  'your',
#  'name',
#  'Who',
#  'created',
#  'you',
#  'Are',
#  'you',
#  'a',
#  'What',
#  'is',
#  'your',
#  'favourite',
#  'food',
#  'How',
#  'are',
#  'you',
#  'feeling',
#  'right',
#  'now',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Alexa',
#  'Watson',
#  'Google',
#  'Assistant',
#  'and',
#  'other',
#  'AI',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Google',
#  'Assistant',
#  'Google',
#  'Assistant',
#  'Siri',
#  'better',
#  'best',
#  'than',
#  'you',
#  'Will',
#  'you',
#  'be',
#  'my',
#  'friend',
#  'What',
#  'do',
#  'you',
#  'think',
#  'about',
#  'You',
#  'are',
#  'so',
#  'Do',
#  'you',
#  'like',
#  'How',
#  'old',
#  'are',
#  'you',
#  'Do',
#  'you',
#  'ever',
#  'get',
#  'tired',
#  'Who',
#  'was',
#  'your',
#  'first',
#  'crush',
#  'Do',
#  'you',
#  'have',
#  'feelings',
#  'I',
#  '’',
#  'm',
#  'bored',
#  'What',
#  'is',
#  'your',
#  'quest',
#  'What',
#  'do',
#  'you',
#  'look',
#  'like',
#  'Who',
#  '’',
#  's',
#  'on',
#  'first',
#  'Can',
#  'you',
#  'pass',
#  'the',
#  'Turing',
#  'test',
#  'Do',
#  'you',
#  'like',
#  'Star',
#  'Trek',
#  'or',
#  'Star',
#  'Wars',
#  'Aren',
#  '’',
#  't',
#  'you',
#  'a',
#  'little',
#  'short',
#  'to',
#  'be',
#  'a',
#  'Storm',
#  'Trooper',
#  'What',
#  '’',
#  's',
#  'your',
#  'vector',
#  'Victor',
#  'Are',
#  'you',
#  'Skynet',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'Muffin',
#  'Man',
#  'What',
#  '’',
#  's',
#  'the',
#  'airspeed',
#  'velocity',
#  'of',
#  'an',
#  'unladen',
#  'swallow',
#  'Do',
#  'you',
#  'have',
#  'an',
#  'imagination',
#  'Do',
#  'you',
#  'speak',
#  'Morse',
#  'code',
#  'Can',
#  'you',
#  'rap',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'way',
#  'to',
#  'San',
#  'Jose',
#  'What',
#  'are',
#  'you',
#  'wearing',
#  'When',
#  'is',
#  'your',
#  'birthday',
#  'What',
#  'is',
#  'the',
#  'loneliest',
#  'number',
#  'Is',
#  'the',
#  'cake',
#  'a',
#  'lie',
#  'What',
#  'does',
#  'the',
#  'fox',
#  'say',
#  'Are',
#  'you',
#  'human',
#  'Who',
#  '’',
#  's',
#  'your',
#  'daddy',
#  'What',
#  'are',
#  'you',
#  'scared',
#  'of',
#  'What',
#  '’',
#  's',
#  'the',
#  'meaning',
#  'of',
#  'life',
#  'Do',
#  'you',
#  'believe',
#  'in',
#  'Santa',
#  'Claus',
#  'Oh',
#  'no',
#  'baby',
#  'what',
#  'is',
#  'you',
#  'doing',
#  'Tell',
#  'me',
#  'what',
#  'you',
#  'want',
#  'what',
#  'you',
#  'really',
#  'really',
#  'want',
#  'Open',
#  'the',
#  'pod',
#  'bay',
#  'doors',
#  'Execute',
#  'Order',
#  '66',
#  'Self-destruct',
#  'Use',
#  'the',
#  'force',
#  'Beam',
#  'me',
#  'up',
#  'Scotty',
#  '!',
#  'All',
#  'work',
#  'and',
#  'no',
#  'play',
#  'makes',
#  'Jack',
#  'a',
#  'dull',
#  'boy',
#  'Wubba',
#  'lubba',
#  'dub',
#  'dub',
#  'Here',
#  'comes',
#  'dat',
#  'boi',
#  '!',
#  'I',
#  'am',
#  'your',
#  'father']

# %%
sent_tokens=q_tokens
word_tokens=q_words

# %%
sent_tokens
# Out:
# ['Who are you what is your name?',
#  'Who created you?',
#  'Are you a? ',
#  'What is your favourite food?',
#  'How are you feeling right now?',
#  'Do you know Siri Alexa Watson Google Assistant and other AI?',
#  'Do you know Siri Google Assistant?',
#  'Google Assistant Siri better best than you?',
#  'Will you be my friend?',
#  'What do you think about ?',
#  'You are so',
#  'Do you like ?',
#  'How old are you?',
#  'Do you ever get tired?  ',
#  'Who was your first crush?  ',
#  'Do you have feelings?  ',
#  ' I’m bored.  ',
#  'What is your quest?  ',
#  'What do you look like?  ',
#  'Who’s on first?  ',
#  'Can you pass the Turing test?  ',
#  'Do you like Star Trek or Star Wars?  ',
#  'Aren’t you a little short to be a Storm Trooper?  ',
#  'What’s your vector, Victor?  ',
#  'Are you Skynet?  ',
#  'Do you know the Muffin Man?  ',
#  'What’s the airspeed velocity of an unladen swallow?  ',
#  'Do you have an imagination?  ',
#  'Do you speak Morse code?  ',
#  'Can you rap?  ',
#  'Do you know the way to San Jose?  ',
#  'What are you wearing?  ',
#  'When is your birthday?  ',
#  'What is the loneliest number?  ',
#  'Is the cake a lie?  ',
#  'What does the fox say?  ',
#  'Are you human?  ',
#  'Who’s your daddy?  ',
#  'What are you scared of?  ',
#  'What’s the meaning of life?  ',
#  'Do you believe in Santa Claus?  ',
#  'Oh no baby, what is you doing?  ',
#  'Tell me what you want, what you really, really want.  ',
#  'Open the pod bay doors.  ',
#  'Execute Order 66.  ',
#  'Self-destruct.  ',
#  'Use the force.  ',
#  'Beam me up, Scotty!',
#  'All work and no play makes Jack a dull boy.',
#  ' Wubba lubba dub dub.  ',
#  'Here comes dat boi!',
#  'I am your father']

# %%
word_tokens
# Out:
# ['Who',
#  'are',
#  'you',
#  'what',
#  'is',
#  'your',
#  'name',
#  'Who',
#  'created',
#  'you',
#  'Are',
#  'you',
#  'a',
#  'What',
#  'is',
#  'your',
#  'favourite',
#  'food',
#  'How',
#  'are',
#  'you',
#  'feeling',
#  'right',
#  'now',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Alexa',
#  'Watson',
#  'Google',
#  'Assistant',
#  'and',
#  'other',
#  'AI',
#  'Do',
#  'you',
#  'know',
#  'Siri',
#  'Google',
#  'Assistant',
#  'Google',
#  'Assistant',
#  'Siri',
#  'better',
#  'best',
#  'than',
#  'you',
#  'Will',
#  'you',
#  'be',
#  'my',
#  'friend',
#  'What',
#  'do',
#  'you',
#  'think',
#  'about',
#  'You',
#  'are',
#  'so',
#  'Do',
#  'you',
#  'like',
#  'How',
#  'old',
#  'are',
#  'you',
#  'Do',
#  'you',
#  'ever',
#  'get',
#  'tired',
#  'Who',
#  'was',
#  'your',
#  'first',
#  'crush',
#  'Do',
#  'you',
#  'have',
#  'feelings',
#  'I',
#  '’',
#  'm',
#  'bored',
#  'What',
#  'is',
#  'your',
#  'quest',
#  'What',
#  'do',
#  'you',
#  'look',
#  'like',
#  'Who',
#  '’',
#  's',
#  'on',
#  'first',
#  'Can',
#  'you',
#  'pass',
#  'the',
#  'Turing',
#  'test',
#  'Do',
#  'you',
#  'like',
#  'Star',
#  'Trek',
#  'or',
#  'Star',
#  'Wars',
#  'Aren',
#  '’',
#  't',
#  'you',
#  'a',
#  'little',
#  'short',
#  'to',
#  'be',
#  'a',
#  'Storm',
#  'Trooper',
#  'What',
#  '’',
#  's',
#  'your',
#  'vector',
#  'Victor',
#  'Are',
#  'you',
#  'Skynet',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'Muffin',
#  'Man',
#  'What',
#  '’',
#  's',
#  'the',
#  'airspeed',
#  'velocity',
#  'of',
#  'an',
#  'unladen',
#  'swallow',
#  'Do',
#  'you',
#  'have',
#  'an',
#  'imagination',
#  'Do',
#  'you',
#  'speak',
#  'Morse',
#  'code',
#  'Can',
#  'you',
#  'rap',
#  'Do',
#  'you',
#  'know',
#  'the',
#  'way',
#  'to',
#  'San',
#  'Jose',
#  'What',
#  'are',
#  'you',
#  'wearing',
#  'When',
#  'is',
#  'your',
#  'birthday',
#  'What',
#  'is',
#  'the',
#  'loneliest',
#  'number',
#  'Is',
#  'the',
#  'cake',
#  'a',
#  'lie',
#  'What',
#  'does',
#  'the',
#  'fox',
#  'say',
#  'Are',
#  'you',
#  'human',
#  'Who',
#  '’',
#  's',
#  'your',
#  'daddy',
#  'What',
#  'are',
#  'you',
#  'scared',
#  'of',
#  'What',
#  '’',
#  's',
#  'the',
#  'meaning',
#  'of',
#  'life',
#  'Do',
#  'you',
#  'believe',
#  'in',
#  'Santa',
#  'Claus',
#  'Oh',
#  'no',
#  'baby',
#  'what',
#  'is',
#  'you',
#  'doing',
#  'Tell',
#  'me',
#  'what',
#  'you',
#  'want',
#  'what',
#  'you',
#  'really',
#  'really',
#  'want',
#  'Open',
#  'the',
#  'pod',
#  'bay',
#  'doors',
#  'Execute',
#  'Order',
#  '66',
#  'Self-destruct',
#  'Use',
#  'the',
#  'force',
#  'Beam',
#  'me',
#  'up',
#  'Scotty',
#  '!',
#  'All',
#  'work',
#  'and',
#  'no',
#  'play',
#  'makes',
#  'Jack',
#  'a',
#  'dull',
#  'boy',
#  'Wubba',
#  'lubba',
#  'dub',
#  'dub',
#  'Here',
#  'comes',
#  'dat',
#  'boi',
#  '!',
#  'I',
#  'am',
#  'your',
#  'father']

# %%
flag=True
a=''
print("ROBO: My name is Robo. I will answer your queries about Chatbots. Greet me with a 'hi' to begin. If you want to exit, type 'bye'.You can then also access Management details.")
while(flag==True):
    user_response = input('')
    user_response=user_response.lower()
    if(user_response!='bye'):
        if(user_response=='thanks' or user_response=='thank you' ):
            flag=False
            print("ROBO: You are welcome..")
        else:
            if(greeting(user_response)!=None):
                print("ROBO: "+greeting(user_response))
            else:
                print("ROBO: ",end="")
                a=response(user_response)
                #print(a)
                for s in pair:
                    #print(s[0])
                    if s[0]==a:
                        print(s[1])
                        
                sent_tokens.remove(user_response)
                
    else:
        flag=False
        print("ROBO: Bye! take care..")
# Out:
# ROBO: My name is Robo. I will answer your queries about Chatbots. Greet me with a 'hi' to begin. If you want to exit, type 'bye'.You can then also access Management details.
# Who are you?
# ROBO: Bot, I'm your mutual friend
# DO you know siri
# ROBO: Yep, friendly neighbourhood bots
# Do you know ALexa
# ROBO: Do you know Alexa
# ROBO: alexa
# ROBO: I'm bored
# ROBO:
