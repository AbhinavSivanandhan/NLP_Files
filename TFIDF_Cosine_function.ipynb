# %%
import nltk
import numpy as np
import random
import string 
f=open('practraincorpus.txt','r',errors = 'ignore')
raw=f.read()
raw=raw.lower()


sent_tokens = nltk.sent_tokenize(raw)
word_tokens = nltk.word_tokenize(raw)

lemmer = nltk.stem.WordNetLemmatizer()

def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def response(user_response):
    robo_response=''
    sent_tokens.append(user_response)
    TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    return req_tfidf

# %%
print(response('what is riviera and does VIT conduct it?'))
# Out:
# 0.28362747843016256

# %%
f=open('practraincorpus2.txt','r',errors = 'ignore')
raw=f.read()
raw=raw.lower()


sent_tokens = nltk.sent_tokenize(raw)
word_tokens = nltk.word_tokenize(raw)

# %%
print(response('what is riviera and does VIT conduct it?'))
# Out:
# 0.16956832030773566

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
punct=['.',',',':','?',';','(',')']
stop_words.union(punct)
# Out:
# {'(',
#  ')',
#  ',',
#  '.',
#  ':',
#  ';',
#  '?',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
# ...

# %%
filtered_sent = [w for w in word_tokens if not w in stop_words]
filtered_sent = [w for w in word_tokens if not w in punc]
t=[]

# %%
word_count=0
for i in filtered_sent:
    word_count+=1
    count=0
    for j in filtered_sent:
        if i==j:
            count+=1        
    t.append([i,count])

# %%
t
# Out:
# [['vellore', 22],
#  ['institute', 32],
#  ['of', 91],
#  ['technology', 22],
#  ['from', 7],
#  ['wikipedia', 5],
#  ['the', 72],
#  ['free', 2],
#  ['encyclopedia', 1],
#  ['jump', 1],
#  ['to', 25],
#  ['navigationjump', 1],
#  ['to', 25],
#  ['search', 2],
#  ['vellore', 22],
#  ['institute', 32],
#  ['of', 91],
#  ['technology', 22],
#  ['vellore', 22],
#  ['institute', 32],
#  ['of', 91],
#  ['technology', 22],
#  ['seal', 1],
#  ['2017.svg', 1],
#  ['former', 2],
#  ['names', 2],
#  ['vellore', 22],
#  ['engineering', 21],
#  ['college', 7],
#  ['type', 1],
#  ['private', 4],
#  ['deemed', 3],
#  ['university', 44],
#  ['institute', 32],
#  ['of', 91],
#  ['eminence', 3],
#  ['founder', 1],
#  ['g.', 4],
#  ['viswanathan', 5],
#  ['chancellor', 1],
#  ['g.', 4],
#  ['viswanathan', 5],
#  ['vice-chancellor', 1],
#  ['anand', 1],
#  ['a.', 1],
#  ['samuel', 1],
#  ['students', 17],
#  ['25000', 1],
#  ['location', 1],
#  ['vellore', 22],
#  ['tamil', 19],
#  ['nadu', 16],
# ...

# %%
word_count
# Out:
# 2448

# %%
tf_array=[]
counst=0
for i in t:
    counst=i[1]/word_count
    #print(type(i[1]))
    tf_array.append([i[0],counst])
#tf_value=
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-0de8e0c22c07> in <module>
#       2 counst=0
#       3 for i in t:
# ----> 4     counst=i[1]/word_count
#       5     #print(type(i[1]))
#       6     tf_array.append([i[0],counst])
#
# TypeError: 'float' object is not subscriptable

# %%
tf_array #TF value
# Out:
# [['vellore', 0.008986928104575163],
#  ['institute', 0.013071895424836602],
#  ['of', 0.037173202614379085],
#  ['technology', 0.008986928104575163],
#  ['from', 0.0028594771241830064],
#  ['wikipedia', 0.002042483660130719],
#  ['the', 0.029411764705882353],
#  ['free', 0.0008169934640522876],
#  ['encyclopedia', 0.0004084967320261438],
#  ['jump', 0.0004084967320261438],
#  ['to', 0.010212418300653595],
#  ['navigationjump', 0.0004084967320261438],
#  ['to', 0.010212418300653595],
#  ['search', 0.0008169934640522876],
#  ['vellore', 0.008986928104575163],
#  ['institute', 0.013071895424836602],
#  ['of', 0.037173202614379085],
#  ['technology', 0.008986928104575163],
#  ['vellore', 0.008986928104575163],
#  ['institute', 0.013071895424836602],
#  ['of', 0.037173202614379085],
#  ['technology', 0.008986928104575163],
#  ['seal', 0.0004084967320261438],
#  ['2017.svg', 0.0004084967320261438],
#  ['former', 0.0008169934640522876],
#  ['names', 0.0008169934640522876],
# ...

# %%
def unique(list1): 
  
    # intilize a null list 
    unique_list = [] 
      
    # traverse for all elements 
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    # print list 
    #for x in unique_list: 
        #print(x)
    return unique_list

# %%
unique(tf_array)  #TF value
# Out:
# ['vellore', 0.008986928104575163]
# ['institute', 0.013071895424836602]
# ['of', 0.037173202614379085]
# ['technology', 0.008986928104575163]
# ['from', 0.0028594771241830064]
# ['wikipedia', 0.002042483660130719]
# ['the', 0.029411764705882353]
# ['free', 0.0008169934640522876]
# ['encyclopedia', 0.0004084967320261438]
# ['jump', 0.0004084967320261438]
# ['to', 0.010212418300653595]
# ['navigationjump', 0.0004084967320261438]
# ['search', 0.0008169934640522876]
# ['seal', 0.0004084967320261438]
# ['2017.svg', 0.0004084967320261438]
# ['former', 0.0008169934640522876]
# ['names', 0.0008169934640522876]
# ['engineering', 0.00857843137254902]
# ['college', 0.0028594771241830064]
# ['type', 0.0004084967320261438]
# ['private', 0.0016339869281045752]
# ['deemed', 0.0012254901960784314]
# ['university', 0.017973856209150325]
# ['eminence', 0.0012254901960784314]
# ['founder', 0.0004084967320261438]
# ['g.', 0.0016339869281045752]
# ['viswanathan', 0.002042483660130719]
# ...

# %%
query='what is riviera and does VIT conduct it?'

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize   
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(query) 
sent=[]
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
punct=['.',',',':','?',';','(',')','?']
#filtered_sentence = [w for w in word_tokens if not w in punct] 
for i in filtered_sentence:
    if i not in punct:
        sent.append(i)
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
#print(word_tokens) 
print(sent) 
query_proc=sent
# Out:
# ['riviera', 'VIT', 'conduct']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances

corpus = [
'All my cats in a row',
'When my cat sits down, she looks like a Furby toy!',
'The cat from outer space',
'Sunshine loves to sit like this for some reason.'
]

vectorizer = CountVectorizer()
features = vectorizer.fit_transform(corpus).todense() 
print( vectorizer.vocabulary_ )

for f in features:
    print( euclidean_distances(features[0], f) )
# Out:
# {'all': 0, 'my': 11, 'cats': 2, 'in': 7, 'row': 14, 'when': 25, 'cat': 1, 'sits': 17, 'down': 3, 'she': 15, 'looks': 9, 'like': 8, 'furby': 6, 'toy': 24, 'the': 21, 'from': 5, 'outer': 12, 'space': 19, 'sunshine': 20, 'loves': 10, 'to': 23, 'sit': 16, 'this': 22, 'for': 4, 'some': 18, 'reason': 13}
# [[0.]]
# [[3.60555128]]
# [[3.16227766]]
# [[3.74165739]]

# %%
query_proc
# Out:
# ['riviera', 'VIT', 'conduct']

# %%
f=open('practraincorpus.txt','r',errors = 'ignore')
raw=f.read()
raw=raw.lower()


sent_tokens = nltk.sent_tokenize(raw)
word_tokens = nltk.word_tokenize(raw)

# %%
f=open('practraincorpus2.txt','r',errors = 'ignore')
raw=f.read()
raw=raw.lower()


sent_tokens2 = nltk.sent_tokenize(raw)
word_tokens2 = nltk.word_tokenize(raw)

# %%
idf_array=[]
u_w1=unique(word_tokens)
u_w2=unique(word_tokens2)

   # else if i[0] not in word_tokens and i[0] in word_tokens2:
#        idf_array.append([i[0],1])
    #else;
        #print(i[0])
        #print(word_tokens)

# %%
import math
for i in u_w1:
    if i in u_w2:
        #print(i)
        idf_array.append([i,math.log(3/2)]) #since log(1+total num of docs / docs )
    else:
        #print(i)
        idf_array.append([i,math.log(3/1)])
for i in u_w2:
    if i not in u_w1:
        idf_array.append([i,3/1])

# %%
idf_array #IDF value
# Out:
# [['riviera', 0.4054651081081644],
#  ['(', 0.4054651081081644],
#  ['festival', 1.0986122886681098],
#  [')', 0.4054651081081644],
#  ['from', 0.4054651081081644],
#  ['wikipedia', 0.4054651081081644],
#  [',', 0.4054651081081644],
#  ['the', 0.4054651081081644],
#  ['free', 0.4054651081081644],
#  ['encyclopedia', 0.4054651081081644],
#  ['jump', 0.4054651081081644],
#  ['to', 0.4054651081081644],
#  ['navigationjump', 0.4054651081081644],
#  ['search', 0.4054651081081644],
#  ['vit', 0.4054651081081644],
#  ['university', 0.4054651081081644],
#  ['vitrivieradp.png', 1.0986122886681098],
#  ['logo', 1.0986122886681098],
#  ['of', 0.4054651081081644],
#  ['genre', 1.0986122886681098],
#  ['sports', 0.4054651081081644],
#  ['and', 0.4054651081081644],
#  ['cultural', 0.4054651081081644],
#  ['carnival', 1.0986122886681098],
#  ['location', 0.4054651081081644],
#  ['s', 1.0986122886681098],
#  ['vellore', 0.4054651081081644],
#  ['india', 0.4054651081081644],
# ...

# %%
tfidf_array=[]
for i in tf_array:
    for j in idf_array:
        if i[0]==j[0]:
            tfidf_array.append([i[0],i[1]*j[1]])

# %%
tfidf_array
# Out:
# [['vellore', 0.017973856209150325],
#  ['institute', 0.026143790849673203],
#  ['of', 0.07434640522875817],
#  ['technology', 0.017973856209150325],
#  ['from', 0.005718954248366013],
#  ['wikipedia', 0.004084967320261438],
#  ['the', 0.058823529411764705],
#  ['free', 0.0016339869281045752],
#  ['encyclopedia', 0.0008169934640522876],
#  ['jump', 0.0008169934640522876],
#  ['to', 0.02042483660130719],
#  ['navigationjump', 0.0008169934640522876],
#  ['to', 0.02042483660130719],
#  ['search', 0.0016339869281045752],
#  ['vellore', 0.017973856209150325],
#  ['institute', 0.026143790849673203],
#  ['of', 0.07434640522875817],
#  ['technology', 0.017973856209150325],
#  ['vellore', 0.017973856209150325],
#  ['institute', 0.026143790849673203],
#  ['of', 0.07434640522875817],
#  ['technology', 0.017973856209150325],
#  ['seal', 0.0004084967320261438],
#  ['2017.svg', 0.0004084967320261438],
#  ['former', 0.0008169934640522876],
#  ['names', 0.0008169934640522876],
# ...

# %%
tfidf_array=unique(tfidf_array)

# %%
#query_proc
# Out:
# ['riviera', 'VIT', 'conduct']

# %%
#a=query_proc

# %%
query_proc=['riviera','vit','conduct']

# %%
tfidf_calc_array=[]
tfidf_word_match=[]
for i in tfidf_array:
    if i[0] in query_proc:
        tfidf_calc_array.append(i[1])
        tfidf_word_match.append(i[0])

# %%
tfidf_calc_array
# Out:
# [0.03431372549019608, 0.0016339869281045752, 0.0004084967320261438]

# %%
tfidf_word_match
# Out:
# ['vit', 'riviera', 'conduct']

# %%
c=0
tfidf_query=[]
for i in tfidf_word_match:
    tfidf_query.append([tfidf_word_match[c],tfidf_calc_array[c]])
    c+=1
#print(c)
#while(<c):

# %%
tfidf_query
# Out:
# [['vit', 0.03431372549019608],
#  ['riviera', 0.0016339869281045752],
#  ['conduct', 0.0004084967320261438]]

# %%
ct=0
for i in query_proc:
    ct+=1
    g=query_proc.count(i)
tf=g/ct
    #print(ct)
# Out:
# 1
# 2
# 3

# %%
score=0
for i in tfidf_query:
    for j in idf_array:
        if(i[0]==j[0]):
            score+=i[1]*j[1]

# %%
score
# Out:
# 0.01580103329800591
